# %%
import pandas as pd

# %%
pd.read_parquet(r'E:\quant\lyquant\dl-for-cta\cache\features\mini_3m_1m_1m')
# Out:
#       order_book_id            datetime        volume       open  \
# 0       000300.XSHG 2015-01-05 09:31:00  1.157069e+09  3566.0890
# 1       000300.XSHG 2015-01-05 09:32:00  5.199013e+08  3567.0830
# 2       000300.XSHG 2015-01-05 09:33:00  4.162799e+08  3566.1950
# 3       000300.XSHG 2015-01-05 09:34:00  3.438035e+08  3572.3900
# 4       000300.XSHG 2015-01-05 09:35:00  3.389296e+08  3575.5830
# ...             ...                 ...           ...        ...
# 23515   000300.XSHG 2015-05-29 14:56:00  1.660011e+08  4838.2389
# 23516   000300.XSHG 2015-05-29 14:57:00  1.885728e+08  4837.8689
# 23517   000300.XSHG 2015-05-29 14:58:00  1.626559e+08  4838.5369
# 23518   000300.XSHG 2015-05-29 14:59:00  1.493728e+08  4839.3269
# 23519   000300.XSHG 2015-05-29 15:00:00  2.702971e+08  4840.7999
#
#        total_turnover       high        low      close     ret_1  mom_gap_1  \
# 0        1.368810e+10  3570.0110  3566.0890  3567.9330       NaN        NaN
# ...
